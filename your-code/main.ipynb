# %% [markdown]
# # Antes de empezar:
#
#     Lee el archivo README.md
#     Comenta todo lo que puedas y utiliza los recursos (archivo README.md)
#     ¡Feliz aprendizaje!

# %% [markdown]
# En este ejercicio, generaremos números aleatorios a partir de las disribuciones continuas que aprendimos en la lección. Hay dos formas de generar números aleatorios:
#
# 1. Usando la librería numpy
# 1. Usando la librería Scipy
#
# Utiliza cualquiera de las dos librerías o ambas en este ejercicio.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math
import seaborn as sns

# %% [markdown]
# ## Distribución Uniforme
#
# Para generar números aleatorios uniformes entre dos valores dados usando scipy, podemos usar el siguiente código o el código que hemos
# discutido en clase:

# %%
# your code here
def generate_uniform_random_numbers(bottom, ceiling, count):
    return np.random.uniform(bottom, ceiling, count)

# %% [markdown]
# **Tarea:**
#
# 1. Basándote en el código anterior, escribe una función que genere números aleatorios uniformemente distribuidos. Hay varios requisitos para tu función:
#     * Debe aceptar 3 parámetros:
#         * `bottom` - el límite inferior de los números generados
#         * `ceiling` - el límite superior de los números generados
#         * `count` - cuántos números generar
#     * Debe devolver una matriz de números aleatorios distribuidos uniformemente
#
# 2. Llama a tu función con 2 conjuntos de parámetros a continuación:
#     * bottom=10, ceiling=15, count=100
#     * bottom=10, ceiling=60, count=1,000
#
# 3. Traza las distribuciones uniformes generadas anteriormente utilizando histogramas, donde el eje x es el valor y el eje y es el recuento. Que el número de intervalos del histograma sea 10.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
# your code here
# Generar números aleatorios uniformemente distribuidos
uniform1 = generate_uniform_random_numbers(10, 15, 100)
uniform2 = generate_uniform_random_numbers(10, 60, 1000)

# %%
# your code here
# Graficar histogramas
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.hist(uniform1, bins=10, edgecolor='black')
plt.title('Uniform Distribution: 10-15, count=100')
plt.xlabel('Value')
plt.ylabel('Count')
plt.gca().set_ylim([0, 130]) 
plt.subplot(1, 2, 2)
plt.hist(uniform2, bins=10, edgecolor='black')
plt.title('Uniform Distribution: 10-60, count=1000')
plt.xlabel('Value')
plt.ylabel('Count')
plt.gca().set_ylim([0, 130]) 
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribución Normal
#
# 1. De la misma manera en el reto de Distribución Uniforme, escriba una función que genere números aleatorios distribuidos normalmente.
# 1. Genera 1.000 números distribuidos normalmente con media de 10 y desviación típica de 1
# 1. Genera 1.000 números distribuidos normalmente con una media de 10 y una desviación típica de 50
# 2. Representa gráficamente las distribuciones de los datos generados.
#
# Resultado esperado:
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import norm

# %%
# your code here
def generate_normal_random_numbers(mean, std, count):
    return norm.rvs(loc=mean, scale=std, size=count)

# %%
# your code here
normal1 = generate_normal_random_numbers(10, 1, 1000)
normal2 = generate_normal_random_numbers(10, 50, 1000)

# %%
# your code here
# Graficar histogramas
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(normal1, bins=100, edgecolor='black')
plt.title('Normal Distribution: mean=10, std=1, count=1000')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(normal2, bins=100, edgecolor='black')
plt.title('Normal Distribution: mean=10, std=50, count=1000')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Distribución Normal de Datos Reales
#
# En este reto vamos a echar un vistazo a los datos reales. Utilizaremos el archivo vehicles.csv para este ejercicio

# %%
# your code here
vehicles = pd.read_csv('vehicles.csv')

# %% [markdown]
# Primero importa vehicles.csv.
# A continuación, traza los histogramas de las siguientes variables:
#
# 1. Barriles de combustible/año
# 2. Emisiones de CO2 Gramos/Milla
# 3. MPG Combinado

# %%
# Graficar histogramas de las variables seleccionadas
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.hist(vehicles['Fuel Barrels/Year'], bins=30, edgecolor='black')
plt.title('Fuel Barrels/Year')
plt.xlabel('Barrels')
plt.ylabel('Count')

plt.subplot(1, 3, 2)
plt.hist(vehicles['CO2 Emission Grams/Mile'], bins=30, edgecolor='black')
plt.title('CO2 Emission Grams/Mile')
plt.xlabel('CO2 Grams/Mile')
plt.ylabel('Count')

plt.subplot(1, 3, 3)
plt.hist(vehicles['Combined MPG'], bins=30, edgecolor='black')
plt.title('Combined MPG')
plt.xlabel('MPG')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ¿Cuál o cuáles de las variables tienen una distribución casi normal? ¿Cómo lo sabes?

# %% [markdown]
# Ninguno de ellos está normalmente ditribuido. Ya que no están centrados en la mitad del eje X

# %% [markdown]
# ## Distribución Exponencial

# %% [markdown]
# 1. Utilizando `numpy.random.exponential`, crea una función que devuelva una lista de números distribuidos exponencialmente con la media de 10.
#
# 1. Utiliza la función para generar dos secuencias de números de tamaño 10 y 100.
#
# 1. 2. Traza las distribuciones como histogramas con el número de bins como 100.
#
# El resultado debe ser como el siguiente:
#
# ![image.png](attachment:image.png)

# %%
# your code here
def generate_exponential_random_numbers(scale, count):
    return np.random.exponential(scale, count)

# %%
# Generar números aleatorios exponencialmente distribuidos
exponential1 = generate_exponential_random_numbers(10, 10)
exponential2 = generate_exponential_random_numbers(10, 100)

# %%
# Graficar histogramas
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(exponential1, bins=30, edgecolor='black')
plt.title('Exponential Distribution: mean=10, count=10')
plt.xlabel('Value')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
plt.hist(exponential2, bins=100, edgecolor='black')
plt.title('Exponential Distribution: mean=10, count=100')
plt.xlabel('Value')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# ¿En qué se diferencian ambas distribuciones?

# %% [markdown]
# La media cambia, por lo que la distribución también cambia.

# %% [markdown]
# ## Distribución Exponencial de datos reales
#
# Supongamos que el tiempo que uno pasa en un banco se distribuye exponencialmente con media de 10 minutos (es decir, λ = 1/10). ¿Cuál es la probabilidad de que un cliente pase menos de quince minutos en el banco?
#
# Escribe un código en python para resolver este problema

# %%
# your code here
from scipy.stats import expon

# Parámetro lambda para la distribución exponencial
lambda_value = 1 / 10

# %%
# your answer here
# Hint: This is same as saying P(x<15)
prob_less_than_15 = expon.cdf(15, scale=1/lambda_value) * 100
print(f"Probabilidad de que un cliente pase menos de 15 minutos en el banco: {prob_less_than_15:.2f}%")
# Out:
# Probabilidad de que un cliente pase menos de 15 minutos en el banco: 77.69%

# %% [markdown]
# ¿Cuál es la probabilidad de que el cliente pase más de 15 minutos?

# %%
# your code here
prob_more_than_15 = (1 - expon.cdf(15, scale=1/lambda_value)) * 100
print(f"Probabilidad de que un cliente pase más de 15 minutos en el banco: {prob_more_than_15:.2f}%")
# Out:
# Probabilidad de que un cliente pase más de 15 minutos en el banco: 22.31%
